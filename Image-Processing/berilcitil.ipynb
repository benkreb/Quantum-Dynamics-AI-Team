# %%
import numpy as np

# %%
import cv2
from matplotlib import pyplot as plt


image_cv2 = cv2.imread('/content/shocked_monkey.jpg')


image_rgb = cv2.cvtColor(image_cv2, cv2.COLOR_BGR2RGB)


plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
my_copy=image_rgb.copy()

# %%
my_copy[:,:,0]=0
my_copy[:,:,1]=0
plt.imshow(my_copy)

# %%
img=cv2.imread('/content/shocked_guy.png')
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
flip_img=img_rgb.copy()
flip_img=cv2.flip(flip_img,0)
plt.imshow(flip_img)

# %%
pt1=(450,950)
pt2=(1080,10)

# %%
cv2.rectangle(img_rgb,pt1=pt1,pt2=pt2,color=(255,0,0),thickness=15)
plt.imshow(img_rgb)

# %%
cat=cv2.imread('/content/shocked_cat.jpg')
cat_rgb=cv2.cvtColor(cat,cv2.COLOR_BGR2RGB)
plt.imshow(cat_rgb)

# %%
cat=cv2.imread('/content/shocked_cat.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(cat, cmap='gray')

# %%
def display_img(img,cmap=None):
  fig=plt.figure(figsize=(12,10))
  ax=fig.add_subplot(111)
  ax.imshow(img,cmap)

# %%
img=cv2.imread('/content/shocked_monkey.jpg',0)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
display_img(img)

# %%
ret,thresh1= cv2.threshold(img,127,255,cv2.THRESH_BINARY)
display_img(thresh1,cmap='gray')

# %%
img=cv2.imread('/content/giraffes.jpg',0)
sobelx= cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
display_img(sobelx,cmap='gray')
